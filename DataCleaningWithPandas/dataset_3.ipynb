# %%
import pandas as pd
import numpy as np

# %%
filename = "data/3.-Badly-Structured-Sales-Data-3.xlsx"
messy_data = pd.read_excel(filename)

# %%
messy_data.head()
# Out:
#        Unnamed: 0            Ship Mode First Class Unnamed: 3   Unnamed: 4  \
# 0             NaN              Segment    Consumer  Corporate  Home Office
# 1        Order ID           Order Date         NaN        NaN          NaN
# 2  CA-2011-100293  2013-03-14 00:00:00         NaN        NaN          NaN
# 3  CA-2011-100706  2013-12-16 00:00:00         NaN        NaN          NaN
# 4  CA-2011-100895  2013-06-02 00:00:00         NaN        NaN          NaN
#
#    Same Day Unnamed: 6   Unnamed: 7 Second Class Unnamed: 9  Unnamed: 10  \
# 0  Consumer  Corporate  Home Office     Consumer  Corporate  Home Office
# 1       NaN        NaN          NaN          NaN        NaN          NaN
# 2       NaN        NaN          NaN          NaN        NaN          NaN
# 3       NaN        NaN          NaN       129.44        NaN          NaN
# 4       NaN        NaN          NaN          NaN        NaN          NaN
#
#   Standard Class Unnamed: 12  Unnamed: 13
# 0       Consumer   Corporate  Home Office
# 1            NaN         NaN          NaN
# 2            NaN         NaN       91.056
# 3            NaN         NaN          NaN
# 4         605.47         NaN          NaN

# %%
messy_data.columns
# Out:
# Index(['Unnamed: 0', 'Ship Mode', 'First Class', 'Unnamed: 3', 'Unnamed: 4',
#        'Same Day', 'Unnamed: 6', 'Unnamed: 7', 'Second Class', 'Unnamed: 9',
#        'Unnamed: 10', 'Standard Class', 'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
messy_data.columns = ['Order ID', 'Order Date', 'First Class_Consumer', 'First Class_Corporate', 'First Class_Home Office',
       'Same Day_Consumer', 'Same Day_Corporate', 'Same Day_Home Office', 'Second Class_Consumer', 'Second Class_Corporate',
       'Second Class_Home Office', 'Standard Class_Consumer', 'Standard Class_Corporate', 'Standard Class_Home Office']

# %%
messy_data.drop([0,1], inplace=True)

# %%
messy_data.set_index(['Order ID','Order Date'], inplace=True)

# %%
messy_data.head()
# Out:
#                           First Class_Consumer First Class_Corporate  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                  NaN                   NaN
# CA-2011-100706 2013-12-16                  NaN                   NaN
# CA-2011-100895 2013-06-02                  NaN                   NaN
# CA-2011-100916 2013-10-21                  NaN                   NaN
# CA-2011-101266 2013-08-27                  NaN                   NaN
#
#                           First Class_Home Office Same Day_Consumer  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                     NaN               NaN
# CA-2011-100706 2013-12-16                     NaN               NaN
# CA-2011-100895 2013-06-02                     NaN               NaN
# CA-2011-100916 2013-10-21                     NaN               NaN
# CA-2011-101266 2013-08-27                     NaN               NaN
#
#                           Same Day_Corporate Same Day_Home Office  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                NaN                  NaN
# CA-2011-100706 2013-12-16                NaN                  NaN
# CA-2011-100895 2013-06-02                NaN                  NaN
# CA-2011-100916 2013-10-21                NaN                  NaN
# CA-2011-101266 2013-08-27                NaN                  NaN
#
#                           Second Class_Consumer Second Class_Corporate  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                   NaN                    NaN
# CA-2011-100706 2013-12-16                129.44                    NaN
# CA-2011-100895 2013-06-02                   NaN                    NaN
# CA-2011-100916 2013-10-21                   NaN                    NaN
# CA-2011-101266 2013-08-27                 13.36                    NaN
#
#                           Second Class_Home Office Standard Class_Consumer  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                      NaN                     NaN
# CA-2011-100706 2013-12-16                      NaN                     NaN
# CA-2011-100895 2013-06-02                      NaN                  605.47
# CA-2011-100916 2013-10-21                      NaN                     NaN
# CA-2011-101266 2013-08-27                      NaN                     NaN
#
#                           Standard Class_Corporate Standard Class_Home Office
# Order ID       Order Date
# CA-2011-100293 2013-03-14                      NaN                     91.056
# CA-2011-100706 2013-12-16                      NaN                        NaN
# CA-2011-100895 2013-06-02                      NaN                        NaN
# CA-2011-100916 2013-10-21                   788.86                        NaN
# CA-2011-101266 2013-08-27                      NaN                        NaN

# %%
messy_data.fillna(0, inplace=True)

# %%
messy_data.apply(pd.to_numeric)
# Out:
#                            First Class_Consumer  First Class_Corporate  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                 0.000                  0.000
# CA-2011-100706 2013-12-16                 0.000                  0.000
# CA-2011-100895 2013-06-02                 0.000                  0.000
# CA-2011-100916 2013-10-21                 0.000                  0.000
# CA-2011-101266 2013-08-27                 0.000                  0.000
# ...                                         ...                    ...
# US-2014-166611 2016-03-28                 0.000                  0.000
# US-2014-167920 2016-12-09                 0.000                  0.000
# US-2014-168116 2016-11-04                 0.000                  0.000
# US-2014-168690 2016-01-08                 0.000                  0.000
# Grand Total    NaT                    20802.173              20792.607
#
#                            First Class_Home Office  Same Day_Consumer  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                    0.000              0.000
# CA-2011-100706 2013-12-16                    0.000              0.000
# CA-2011-100895 2013-06-02                    0.000              0.000
# CA-2011-100916 2013-10-21                    0.000              0.000
# CA-2011-101266 2013-08-27                    0.000              0.000
# ...                                            ...                ...
# US-2014-166611 2016-03-28                    0.000              0.000
# US-2014-167920 2016-12-09                    0.000              0.000
# US-2014-168116 2016-11-04                    0.000              0.000
# US-2014-168690 2016-01-08                    0.000              0.000
# Grand Total    NaT                        7737.786           8132.409
#
#                            Same Day_Corporate  Same Day_Home Office  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14               0.000                 0.000
# CA-2011-100706 2013-12-16               0.000                 0.000
# CA-2011-100895 2013-06-02               0.000                 0.000
# CA-2011-100916 2013-10-21               0.000                 0.000
# CA-2011-101266 2013-08-27               0.000                 0.000
# ...                                       ...                   ...
# US-2014-166611 2016-03-28               0.000                 0.000
# US-2014-167920 2016-12-09               0.000                 0.000
# US-2014-168116 2016-11-04            8167.420                 0.000
# US-2014-168690 2016-01-08               0.000                 0.000
# Grand Total    NaT                   9907.308              2977.456
#
#                            Second Class_Consumer  Second Class_Corporate  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                 0.0000                   0.000
# CA-2011-100706 2013-12-16               129.4400                   0.000
# CA-2011-100895 2013-06-02                 0.0000                   0.000
# CA-2011-100916 2013-10-21                 0.0000                   0.000
# CA-2011-101266 2013-08-27                13.3600                   0.000
# ...                                          ...                     ...
# US-2014-166611 2016-03-28                 0.0000                   0.000
# US-2014-167920 2016-12-09              1827.5100                   0.000
# US-2014-168116 2016-11-04                 0.0000                   0.000
# US-2014-168690 2016-01-08                 0.0000                   0.000
# Grand Total    NaT                    49724.2545               35243.231
#
#                            Second Class_Home Office  Standard Class_Consumer  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                     0.000                   0.0000
# CA-2011-100706 2013-12-16                     0.000                   0.0000
# CA-2011-100895 2013-06-02                     0.000                 605.4700
# CA-2011-100916 2013-10-21                     0.000                   0.0000
# CA-2011-101266 2013-08-27                     0.000                   0.0000
# ...                                             ...                      ...
# US-2014-166611 2016-03-28                     0.000                   0.0000
# US-2014-167920 2016-12-09                     0.000                   0.0000
# US-2014-168116 2016-11-04                     0.000                   0.0000
# US-2014-168690 2016-01-08                     0.000                   2.8080
# Grand Total    NaT                         8791.127              116922.1345
#
#                            Standard Class_Corporate  \
# Order ID       Order Date
# CA-2011-100293 2013-03-14                    0.0000
# CA-2011-100706 2013-12-16                    0.0000
# CA-2011-100895 2013-06-02                    0.0000
# CA-2011-100916 2013-10-21                  788.8600
# CA-2011-101266 2013-08-27                    0.0000
# ...                                             ...
# US-2014-166611 2016-03-28                   68.7420
# US-2014-167920 2016-12-09                    0.0000
# US-2014-168116 2016-11-04                    0.0000
# US-2014-168690 2016-01-08                    0.0000
# Grand Total    NaT                       55942.7865
#
#                            Standard Class_Home Office
# Order ID       Order Date
# CA-2011-100293 2013-03-14                     91.0560
# CA-2011-100706 2013-12-16                      0.0000
# CA-2011-100895 2013-06-02                      0.0000
# CA-2011-100916 2013-10-21                      0.0000
# CA-2011-101266 2013-08-27                      0.0000
# ...                                               ...
# US-2014-166611 2016-03-28                      0.0000
# US-2014-167920 2016-12-09                      0.0000
# US-2014-168116 2016-11-04                      0.0000
# US-2014-168690 2016-01-08                      0.0000
# Grand Total    NaT                         54748.6325
#
# [823 rows x 12 columns]

# %%
messy_data['Segment'] = messy_data.apply(lambda x: messy_data.columns[x.argmax()], axis = 1)

# %%
messy_data["Total"] = messy_data.sum(axis=1)
# Out:
# C:\Users\Admin\AppData\Local\Temp/ipykernel_9536/1309227500.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   messy_data["Total"] = messy_data.sum(axis=1)

# %%
messy_data.columns
# Out:
# Index(['First Class_Consumer', 'First Class_Corporate',
#        'First Class_Home Office', 'Same Day_Consumer', 'Same Day_Corporate',
#        'Same Day_Home Office', 'Second Class_Consumer',
#        'Second Class_Corporate', 'Second Class_Home Office',
#        'Standard Class_Consumer', 'Standard Class_Corporate',
#        'Standard Class_Home Office', 'Segment', 'Total'],
#       dtype='object')

# %%
messy_data.drop(['First Class_Consumer', 'First Class_Corporate',
       'First Class_Home Office', 'Same Day_Consumer', 'Same Day_Corporate',
       'Same Day_Home Office', 'Second Class_Consumer',
       'Second Class_Corporate', 'Second Class_Home Office',
       'Standard Class_Consumer', 'Standard Class_Corporate',
       'Standard Class_Home Office'] , axis=1, inplace=True)

# %%
messy_data.head()
# Out:
#                                               Segment    Total
# Order ID       Order Date
# CA-2011-100293 2013-03-14  Standard Class_Home Office   91.056
# CA-2011-100706 2013-12-16       Second Class_Consumer  129.440
# CA-2011-100895 2013-06-02     Standard Class_Consumer  605.470
# CA-2011-100916 2013-10-21    Standard Class_Corporate  788.860
# CA-2011-101266 2013-08-27       Second Class_Consumer   13.360

# %%
segments = messy_data["Segment"].str.split("_")
segments = segments.to_list()
messy_data["Segment"] = [segments[i][0] for i in range(len(segments))]
messy_data["Class"] = [segments[i][1] for i in range(len(segments))]

# %%
messy_data.head().T
# Out:
# Order ID    CA-2011-100293 CA-2011-100706  CA-2011-100895  CA-2011-100916  \
# Order Date      2013-03-14     2013-12-16      2013-06-02      2013-10-21
# Segment     Standard Class   Second Class  Standard Class  Standard Class
# Total               91.056         129.44          605.47          788.86
# Class          Home Office       Consumer        Consumer       Corporate
#
# Order ID   CA-2011-101266
# Order Date     2013-08-27
# Segment      Second Class
# Total               13.36
# Class            Consumer
